# %%
from pandas_datareader import data as pdr #read data from yahoo finance api
import matplotlib.pyplot as plt #viz #GUI manager
import seaborn as sns #viz #plotly is another package
import datetime 
import pandas as pd
import numpy as np
from pandas import Grouper #groupby
#statistical data exploration, conducting statistical tests, and estimation of different statistical models
import statsmodels.api as sm 
from statsmodels.graphics.tsaplots import plot_acf #autocorrelation plot
from statsmodels.tsa.api import SimpleExpSmoothing
from statsmodels.tsa.holtwinters import ExponentialSmoothing # double and triple exponential smoothing
from pandas.plotting import autocorrelation_plot #autocorrelation plot
from statsmodels.graphics.gofplots import qqplot #residual diagnostics
from sklearn.metrics import mean_squared_error #accuracy metrics
from math import sqrt
from sklearn.metrics import mean_absolute_error #accuracy metrics

from random import gauss #create gaussian white noise
from random import seed
from pandas import Series 
from datetime import datetime

# %%
crop_land_data = pd.read_csv('G:\My Drive\CMU\Summer2022\Time Series Forecasting\wheat_yield_data.txt', sep='\t')

# %%
crop_land_data['Year'] = pd.to_datetime(crop_land_data['Year'], format='%Y')
crop_land_data
# Out:
#                 State     District       Year Year_Extra       Season  \
# 0      Andhra Pradesh   1.ADILABAD 1998-01-01    1997-98  Rabi
# 1      Andhra Pradesh   1.ADILABAD 1999-01-01    1998-99  Rabi
# 2      Andhra Pradesh   1.ADILABAD 2000-01-01    1999-00  Rabi
# 3      Andhra Pradesh   1.ADILABAD 2001-01-01    2000-01  Rabi
# 4      Andhra Pradesh   1.ADILABAD 2002-01-01    2001-02  Rabi
# ...               ...          ...        ...        ...          ...
# 10753     West Bengal   22.PURULIA 2016-01-01    2015-16  Rabi
# 10754     West Bengal   22.PURULIA 2017-01-01    2016-17  Rabi
# 10755     West Bengal   22.PURULIA 2018-01-01    2017-18  Rabi
# 10756     West Bengal   22.PURULIA 2019-01-01    2018-19  Rabi
# 10757     West Bengal   22.PURULIA 2020-01-01    2019-20  Rabi
#
#        Area (Hectare)  Production (Tonnes)  Yield (Tonnes/Hectare)
# 0              3600.0               2000.0                    0.56
# 1              2800.0               1600.0                    0.57
# 2              3964.0               2656.0                    0.67
# 3              3681.0               1848.0                    0.50
# 4              3721.0               3327.0                    0.89
# ...               ...                  ...                     ...
# 10753           855.0               1241.0                    1.45
# 10754          1366.0               2415.0                    1.77
# 10755          1052.0               2145.0                    2.04
# 10756           833.0               2114.0                    2.54
# 10757           516.0                931.0                    1.80
#
# [10758 rows x 8 columns]

# %%
region_data = crop_land_data[(crop_land_data['Year'] == '2020-01-01')]

# %%
region_data
# Out:
#                    State                   District       Year Year_Extra  \
# 33        Andhra Pradesh                2.ANANTAPUR 2020-01-01    2019-20
# 41        Andhra Pradesh                   4.GUNTUR 2020-01-01    2019-20
# 60        Andhra Pradesh                   5.KADAPA 2020-01-01    2019-20
# 95        Andhra Pradesh                  7.KURNOOL 2020-01-01    2019-20
# 203    Arunachal Pradesh                2.CHANGLANG 2020-01-01    2019-20
# ...                  ...                        ...        ...        ...
# 10686        West Bengal             18.MURSHIDABAD 2020-01-01    2019-20
# 10707        West Bengal                   19.NADIA 2020-01-01    2019-20
# 10711        West Bengal   20.PASCHIM BARDHAMAN\r\n 2020-01-01    2019-20
# 10734        West Bengal         21.PURBA BARDHAMAN 2020-01-01    2019-20
# 10757        West Bengal                 22.PURULIA 2020-01-01    2019-20
#
#             Season  Area (Hectare)  Production (Tonnes)  \
# 33     Rabi                   10.0                  3.0
# 41     Rabi                    1.0                  NaN
# 60     Rabi                    1.0                  NaN
# 95     Rabi                   25.0                  8.0
# 203    Rabi                  375.0                862.0
# ...            ...             ...                  ...
# 10686  Rabi                52709.0             136454.0
# 10707  Rabi                 6188.0              16748.0
# 10711  Rabi                  929.0               3946.0
# 10734  Rabi                 1832.0               5678.0
# 10757  Rabi                  516.0                931.0
#
#        Yield (Tonnes/Hectare)
# 33                       0.30
# 41                       0.00
# 60                       0.00
# 95                       0.32
# 203                      2.30
# ...                       ...
# 10686                    2.59
# 10707                    2.71
# 10711                    4.25
# 10734                    3.10
# 10757                    1.80
#
# [466 rows x 8 columns]

# %%
set_region = region_data['District'].unique()
set_region
# Out:
# array([' 2.ANANTAPUR', ' 4.GUNTUR', ' 5.KADAPA', ' 7.KURNOOL',
#        ' 2.CHANGLANG', ' 4.EAST KAMENG', ' 5.EAST SIANG', ' 7.LOHIT',
#        ' 8.LOWER DIBANG VALLEY', ' 9.LOWER SIANG', ' 11.NAMSAI',
#        ' 12.PAKKE KESSANG', ' 13.PAPUM PARE', ' 14.TAWANG', ' 15.TIRAP',
#        ' 18.WEST KAMENG', ' 1.BAKSA', ' 2.BARPETA', ' 3.BONGAIGAON',
#        ' 4.CACHAR', ' 5.CHIRANG', ' 6.DARRANG', ' 7.DHEMAJI', ' 8.DHUBRI',
#        ' 9.DIBRUGARH', ' 11.GOALPARA', ' 12.GOLAGHAT', ' 13.HAILAKANDI',
#        ' 14.JORHAT', ' 15.KAMRUP', ' 16.KAMRUP METRO', ' 19.KOKRAJHAR',
#        ' 20.LAKHIMPUR', ' 21.MARIGAON', ' 22.NAGAON', ' 23.NALBARI',
#        ' 24.SIVASAGAR', ' 25.SONITPUR', ' 26.TINSUKIA', ' 27.UDALGURI',
#        ' 1.ARARIA', ' 2.ARWAL', ' 3.AURANGABAD', ' 4.BANKA',
#        ' 5.BEGUSARAI', ' 6.BHAGALPUR', ' 7.BHOJPUR', ' 9.BUXAR',
#        ' 11.DARBHANGA', ' 17.GAYA', ' 20.GOPALGANJ', ' 23.JAMUI',
#        ' 24.JEHANABAD', ' 25.KAIMUR (BHABUA)', ' 26.KATIHAR',
#        ' 27.KHAGARIA', ' 28.KISHANGANJ', ' 30.LAKHISARAI',
#        ' 32.MADHEPURA', ' 33.MADHUBANI', ' 34.MUNGER', ' 35.MUZAFFARPUR',
#        ' 36.NALANDA', ' 37.NAWADA', ' 40.PASHCHIM CHAMPARAN', ' 41.PATNA',
#        ' 42.PURBI CHAMPARAN', ' 43.PURNIA', ' 45.ROHTAS', ' 46.SAHARSA',
#        ' 48.SAMASTIPUR', ' 49.SARAN', ' 50.SHEIKHPURA', ' 51.SHEOHAR',
#        ' 52.SITAMARHI', ' 53.SIWAN', ' 54.SUPAUL', ' 55.VAISHALI',
#        ' 1.CHANDIGARH', ' 1.DADRA AND NAGAR HAVELI', ' 2.DELHI_TOTAL',
#        ' 1.AHMADABAD', ' 2.AMRELI', ' 3.ANAND', ' 4.ARAVALLI',
#        ' 5.BANAS KANTHA', ' 6.BHARUCH', ' 7.BHAVNAGAR', ' 8.BOTAD',
#        ' 9.CHHOTAUDEPUR', ' 10.DANG', ' 11.DEVBHUMI DWARKA', ' 12.DOHAD',
#        ' 13.GANDHINAGAR', ' 14.GIR SOMNATH', ' 15.JAMNAGAR',
#        ' 16.JUNAGADH', ' 17.KACHCHH', ' 18.KHEDA', ' 19.MAHESANA',
#        ' 20.MAHISAGAR', ' 21.MORBI', ' 22.NARMADA', ' 23.NAVSARI',
#        ' 24.PANCH MAHALS', ' 25.PATAN', ' 26.PORBANDAR', ' 27.RAJKOT',
#        ' 28.SABAR KANTHA', ' 29.SURAT', ' 30.SURENDRANAGAR', ' 31.TAPI',
#        ' 32.VADODARA', ' 1.BILASPUR', ' 2.CHAMBA', ' 3.HAMIRPUR',
#        ' 4.KANGRA', ' 5.KINNAUR', ' 6.KULLU', ' 7.LAHUL AND SPITI',
#        ' 8.MANDI', ' 9.SHIMLA', ' 10.SIRMAUR', ' 11.SOLAN', ' 12.UNA',
#        ' 2.BADGAM', ' 4.DODA', ' 5.JAMMU', ' 7.KATHUA', ' 8.KISHTWAR',
#        ' 12.POONCH', ' 13.PULWAMA', ' 14.RAJAURI', ' 15.RAMBAN',
#        ' 16.REASI', ' 17.SAMBA', ' 19.UDHAMPUR', ' 1.BOKARO', ' 2.CHATRA',
#        ' 3.DEOGHAR', ' 4.DHANBAD', ' 5.DUMKA', ' 6.EAST SINGHBUM',
#        ' 7.GARHWA', ' 8.GIRIDIH', ' 9.GODDA', ' 10.GUMLA',
#        ' 11.HAZARIBAGH', ' 12.JAMTARA', ' 13.KHUNTI', ' 14.KODERMA',
#        ' 15.LATEHAR', ' 16.LOHARDAGA', ' 17.PAKUR', ' 18.PALAMU',
#        ' 19.RAMGARH', ' 20.RANCHI', ' 21.SAHEBGANJ',
#        ' 22.SARAIKELA KHARSAWAN', ' 23.SIMDEGA', ' 24.WEST SINGHBHUM',
#        ' 1.BAGALKOT', ' 3.BELGAUM', ' 4.BELLARY', ' 6.BIDAR',
#        ' 7.BIJAPUR', ' 8.CHAMARAJANAGAR', ' 9.CHIKBALLAPUR',
#        ' 10.CHIKMAGALUR', ' 11.CHITRADURGA', ' 12.DAKSHIN KANNAD',
#        ' 13.DAVANGERE', ' 14.DHARWAD', ' 15.GADAG', ' 16.GULBARGA',
#        ' 17.HASSAN', ' 18.HAVERI', ' 20.KOLAR', ' 21.KOPPAL',
#        ' 22.MANDYA', ' 23.MYSORE', ' 24.RAICHUR', ' 25.RAMANAGARA',
#        ' 27.TUMKUR', ' 29.YADGIR', ' 1.AGAR MALWA', ' 2.ALIRAJPUR',
#        ' 3.ANUPPUR', ' 4.ASHOKNAGAR', ' 5.BALAGHAT', ' 6.BARWANI',
#        ' 8.BETUL', ' 9.BHIND', ' 10.BHOPAL', ' 12.BURHANPUR',
#        ' 13.CHHATARPUR', ' 14.CHHINDWARA', ' 15.DAMOH', ' 16.DATIA',
#        ' 17.DEWAS', ' 19.DHAR', ' 20.DINDORI', ' 22.GUNA', ' 23.GWALIOR',
#        ' 24.HARDA', ' 25.HOSHANGABAD', ' 26.INDORE', ' 27.JABALPUR',
#        ' 30.JHABUA', ' 33.KATNI', ' 34.KHANDWA', ' 35.KHARGONE',
#        ' 39.MANDLA', ' 40.MANDSAUR', ' 41.MORENA', ' 42.NARSINGHPUR',
#        ' 43.NEEMUCH', ' 44.NIWARI', ' 45.PANNA', ' 47.RAISEN',
#        ' 48.RAJGARH', ' 50.RATLAM', ' 51.REWA', ' 52.SAGAR', ' 53.SATNA',
#        ' 54.SEHORE', ' 55.SEONI', ' 56.SHAHDOL', ' 57.SHAJAPUR',
#        ' 58.SHEOPUR', ' 59.SHIVPURI', ' 60.SIDHI', ' 61.SINGRAULI',
#        ' 63.TIKAMGARH', ' 64.UJJAIN', ' 65.UMARIA', ' 66.VIDISHA',
#        ' 1.AHMEDNAGAR', ' 2.AKOLA', ' 3.AMRAVATI', ' 4.AURANGABAD',
#        ' 5.BEED', ' 6.BHANDARA', ' 7.BULDHANA', ' 8.CHANDRAPUR',
#        ' 9.DHULE', ' 10.GADCHIROLI', ' 11.GONDIA', ' 12.HINGOLI',
#        ' 13.JALGAON', ' 14.JALNA', ' 15.KOLHAPUR', ' 16.LATUR',
#        ' 17.NAGPUR', ' 18.NANDED', ' 19.NANDURBAR', ' 20.NASHIK',
#        ' 21.OSMANABAD', ' 22.PALGHAR', ' 23.PARBHANI', ' 24.PUNE',
#        ' 26.SANGLI', ' 27.SATARA', ' 28.SOLAPUR', ' 30.WARDHA',
#        ' 31.WASHIM', ' 32.YAVATMAL', ' 1.EAST GARO HILLS',
#        ' 2.NORTH GARO HILLS', ' 4.SOUTH WEST GARO HILLS',
#        ' 5.WEST GARO HILLS', ' 6.WEST KHASI HILLS', ' 1.DIMAPUR',
#        ' 2.KOHIMA', ' 3.MOKOKCHUNG', ' 4.MON', ' 5.PEREN', ' 6.PHEK',
#        ' 7.TUENSANG', ' 8.WOKHA', ' 9.ZUNHEBOTO', ' 1.AMRITSAR',
#        ' 2.BARNALA', ' 3.BATHINDA', ' 4.FARIDKOT', ' 5.FATEHGARH SAHIB',
#        ' 6.FAZILKA', ' 7.FIROZEPUR', ' 8.GURDASPUR', ' 9.HOSHIARPUR',
#        ' 10.JALANDHAR', ' 11.KAPURTHALA', ' 12.LUDHIANA', ' 13.MANSA',
#        ' 14.MOGA', ' 15.MUKTSAR', ' 16.NAWANSHAHR', ' 17.PATHANKOT',
#        ' 18.PATIALA', ' 19.RUPNAGAR', ' 20.S.A.S NAGAR', ' 21.SANGRUR',
#        ' 22.TARN TARAN', ' 1.AJMER', ' 2.ALWAR', ' 3.BANSWARA',
#        ' 4.BARAN', ' 5.BARMER', ' 6.BHARATPUR', ' 7.BHILWARA',
#        ' 8.BIKANER', ' 9.BUNDI', ' 10.CHITTORGARH', ' 11.CHURU',
#        ' 12.DAUSA', ' 13.DHOLPUR', ' 14.DUNGARPUR', ' 15.GANGANAGAR',
#        ' 16.HANUMANGARH', ' 17.JAIPUR', ' 18.JAISALMER', ' 19.JALORE',
#        ' 20.JHALAWAR', ' 21.JHUNJHUNU', ' 22.JODHPUR', ' 23.KARAULI',
#        ' 24.KOTA', ' 25.NAGAUR', ' 26.PALI', ' 27.PRATAPGARH',
#        ' 28.RAJSAMAND', ' 29.SAWAI MADHOPUR', ' 30.SIKAR', ' 31.SIROHI',
#        ' 32.TONK', ' 33.UDAIPUR', ' 1.EAST DISTRICT', ' 2.NORTH DISTRICT',
#        ' 1.ADILABAD', ' 2.JOGULAMBA', ' 3.KAMAREDDY',
#        ' 4.KOMARAM BHEEM ASIFABAD', ' 6.MANCHERIAL', ' 7.MEDAK',
#        ' 10.NIRMAL', ' 11.NIZAMABAD', ' 12.RAJANNA', ' 13.RANGAREDDI',
#        ' 14.SANGAREDDY', ' 15.SIDDIPET', ' 16.VIKARABAD', ' 1.DHALAI',
#        ' 2.GOMATI', ' 3.KHOWAI', ' 5.SEPAHIJALA', ' 7.UNAKOTI',
#        ' 8.WEST TRIPURA', ' 1.AGRA', ' 2.ALIGARH', ' 3.ALLAHABAD',
#        ' 5.AMBEDKAR NAGAR', ' 6.AMETHI', ' 7.AMROHA', ' 8.AURAIYA',
#        ' 9.AZAMGARH', ' 11.BAGHPAT', ' 12.BAHRAICH', ' 13.BALLIA',
#        ' 14.BALRAMPUR', ' 15.BANDA', ' 16.BARABANKI', ' 17.BAREILLY',
#        ' 18.BASTI', ' 19.BIJNOR', ' 20.BUDAUN', ' 21.BULANDSHAHR',
#        ' 24.CHANDAULI', ' 25.CHITRAKOOT', ' 27.DEORIA', ' 28.ETAH',
#        ' 29.ETAWAH', ' 30.FAIZABAD', ' 31.FARRUKHABAD', ' 32.FATEHPUR',
#        ' 33.FIROZABAD', ' 34.GAUTAM BUDDHA NAGAR', ' 35.GHAZIABAD',
#        ' 36.GHAZIPUR', ' 37.GONDA', ' 38.GORAKHPUR', ' 39.HAMIRPUR',
#        ' 40.HAPUR', ' 41.HARDOI', ' 43.HATHRAS', ' 44.JALAUN',
#        ' 45.JAUNPUR', ' 46.JHANSI', ' 47.KANNAUJ', ' 48.KANPUR DEHAT',
#        ' 49.KANPUR NAGAR', ' 50.KASGANJ', ' 51.KAUSHAMBI', ' 52.KHERI',
#        ' 53.KUSHI NAGAR', ' 54.LALITPUR', ' 55.LUCKNOW',
#        ' 56.MAHARAJGANJ', ' 57.MAHOBA', ' 58.MAINPURI', ' 59.MATHURA',
#        ' 60.MAU', ' 61.MEERUT', ' 62.MIRZAPUR', ' 63.MORADABAD',
#        ' 64.MUZAFFARNAGAR', ' 67.PILIBHIT', ' 69.PRATAPGARH',
#        ' 70.RAE BARELI', ' 71.RAMPUR', ' 73.SAHARANPUR', ' 74.SAMBHAL',
#        ' 75.SANT KABEER NAGAR', ' 76.SANT RAVIDAS NAGAR',
#        ' 77.SHAHJAHANPUR', ' 78.SHAMLI', ' 79.SHRAVASTI',
#        ' 80.SIDDHARTH NAGAR', ' 81.SITAPUR', ' 82.SONBHADRA',
#        ' 83.SULTANPUR', ' 86.UNNAO', ' 88.VARANASI', ' 1.ALMORA',
#        ' 2.BAGESHWAR', ' 3.CHAMOLI', ' 4.CHAMPAWAT', ' 5.DEHRADUN',
#        ' 6.HARIDWAR', ' 7.NAINITAL', ' 8.PAURI GARHWAL', ' 9.PITHORAGARH',
#        ' 10.RUDRA PRAYAG', ' 11.TEHRI GARHWAL', ' 12.UDAM SINGH NAGAR',
#        ' 13.UTTAR KASHI', ' 1.24 PARAGANAS NORTH',
#        ' 2.24 PARAGANAS SOUTH', ' 3.ALIPURDUAR', ' 4.BANKURA',
#        ' 5.BIRBHUM', ' 6.COOCHBEHAR', ' 7.DARJEELING',
#        ' 8.DINAJPUR DAKSHIN', ' 9.DINAJPUR UTTAR', ' 10.HOOGHLY',
#        ' 11.HOWRAH', ' 12.JALPAIGURI', ' 13.JHARGRAM\r\n',
#        ' 14.KALIMPONG\r\n', ' 15.MALDAH', ' 17.MEDINIPUR WEST',
#        ' 18.MURSHIDABAD', ' 19.NADIA', ' 20.PASCHIM BARDHAMAN\r\n',
#        ' 21.PURBA BARDHAMAN', ' 22.PURULIA'], dtype=object)

# %%
crop_land_data = crop_land_data[crop_land_data['District'].isin(set_region)]

# %%
crop_land_data
# Out:
#                 State     District       Year Year_Extra       Season  \
# 0      Andhra Pradesh   1.ADILABAD 1998-01-01    1997-98  Rabi
# 1      Andhra Pradesh   1.ADILABAD 1999-01-01    1998-99  Rabi
# 2      Andhra Pradesh   1.ADILABAD 2000-01-01    1999-00  Rabi
# 3      Andhra Pradesh   1.ADILABAD 2001-01-01    2000-01  Rabi
# 4      Andhra Pradesh   1.ADILABAD 2002-01-01    2001-02  Rabi
# ...               ...          ...        ...        ...          ...
# 10753     West Bengal   22.PURULIA 2016-01-01    2015-16  Rabi
# 10754     West Bengal   22.PURULIA 2017-01-01    2016-17  Rabi
# 10755     West Bengal   22.PURULIA 2018-01-01    2017-18  Rabi
# 10756     West Bengal   22.PURULIA 2019-01-01    2018-19  Rabi
# 10757     West Bengal   22.PURULIA 2020-01-01    2019-20  Rabi
#
#        Area (Hectare)  Production (Tonnes)  Yield (Tonnes/Hectare)
# 0              3600.0               2000.0                    0.56
# 1              2800.0               1600.0                    0.57
# 2              3964.0               2656.0                    0.67
# 3              3681.0               1848.0                    0.50
# 4              3721.0               3327.0                    0.89
# ...               ...                  ...                     ...
# 10753           855.0               1241.0                    1.45
# 10754          1366.0               2415.0                    1.77
# 10755          1052.0               2145.0                    2.04
# 10756           833.0               2114.0                    2.54
# 10757           516.0                931.0                    1.80
#
# [9143 rows x 8 columns]

# %%
crop_land_data['Year'] = pd.DatetimeIndex(crop_land_data['Year']).year
crop_land_data
# Out:
# C:\Users\kanis\AppData\Local\Temp/ipykernel_20536/69909284.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   crop_land_data['Year'] = pd.DatetimeIndex(crop_land_data['Year']).year
#                 State     District  Year Year_Extra       Season  \
# 0      Andhra Pradesh   1.ADILABAD  1998    1997-98  Rabi
# 1      Andhra Pradesh   1.ADILABAD  1999    1998-99  Rabi
# 2      Andhra Pradesh   1.ADILABAD  2000    1999-00  Rabi
# 3      Andhra Pradesh   1.ADILABAD  2001    2000-01  Rabi
# 4      Andhra Pradesh   1.ADILABAD  2002    2001-02  Rabi
# ...               ...          ...   ...        ...          ...
# 10753     West Bengal   22.PURULIA  2016    2015-16  Rabi
# 10754     West Bengal   22.PURULIA  2017    2016-17  Rabi
# 10755     West Bengal   22.PURULIA  2018    2017-18  Rabi
# 10756     West Bengal   22.PURULIA  2019    2018-19  Rabi
# 10757     West Bengal   22.PURULIA  2020    2019-20  Rabi
#
#        Area (Hectare)  Production (Tonnes)  Yield (Tonnes/Hectare)
# 0              3600.0               2000.0                    0.56
# 1              2800.0               1600.0                    0.57
# 2              3964.0               2656.0                    0.67
# 3              3681.0               1848.0                    0.50
# 4              3721.0               3327.0                    0.89
# ...               ...                  ...                     ...
# 10753           855.0               1241.0                    1.45
# 10754          1366.0               2415.0                    1.77
# 10755          1052.0               2145.0                    2.04
# 10756           833.0               2114.0                    2.54
# 10757           516.0                931.0                    1.80
#
# [9143 rows x 8 columns]

# %%
crop_price_data = pd.read_csv('G:\My Drive\CMU\Summer2022\Time Series Forecasting\wheat_data.txt', sep='\t')

# %%
crop_price_data
# Out:
#          Month     Price
# 0     5/1/2002   5951.54
# 1     6/1/2002   6464.34
# 2     7/1/2002   7280.94
# 3     8/1/2002   7835.70
# 4     9/1/2002   9099.18
# ..         ...       ...
# 235  12/1/2021  28463.96
# 236   1/1/2022  27861.55
# 237   2/1/2022  29300.08
# 238   3/1/2022  37077.69
# 239   4/1/2022  37731.30
#
# [240 rows x 2 columns]

# %%
crop_price_data['Month'] = pd.to_datetime(crop_price_data['Month'])
crop_price_data['Price'] = crop_price_data['Price'].astype(float)
crop_price_data = crop_price_data.set_index(crop_price_data['Month'])
crop_price_data
# Out:
#                 Month     Price
# Month
# 2002-05-01 2002-05-01   5951.54
# 2002-06-01 2002-06-01   6464.34
# 2002-07-01 2002-07-01   7280.94
# 2002-08-01 2002-08-01   7835.70
# 2002-09-01 2002-09-01   9099.18
# ...               ...       ...
# 2021-12-01 2021-12-01  28463.96
# 2022-01-01 2022-01-01  27861.55
# 2022-02-01 2022-02-01  29300.08
# 2022-03-01 2022-03-01  37077.69
# 2022-04-01 2022-04-01  37731.30
#
# [240 rows x 2 columns]

# %%
crop_price_data.drop(columns={'Month'},inplace=True)

# %%
crop_price_data = crop_price_data.resample('Y').sum()/12

# %%
crop_price_data
# Out:
#                    Price
# Month
# 2002-12-31   5184.855833
# 2003-12-31   6804.928333
# 2004-12-31   7105.751667
# 2005-12-31   6724.467500
# 2006-12-31   8705.698333
# 2007-12-31  10467.359167
# 2008-12-31  13961.342500
# 2009-12-31  10857.124167
# 2010-12-31  10204.839167
# 2011-12-31  14702.228333
# 2012-12-31  16772.254167
# 2013-12-31  18275.793333
# 2014-12-31  17371.544167
# 2015-12-31  13077.181667
# 2016-12-31  11196.448333
# 2017-12-31  11332.466667
# 2018-12-31  14379.769167
# 2019-12-31  14203.464167
# 2020-12-31  17149.716667
# 2021-12-31  23329.309167
# 2022-12-31  10997.551667

# %%
crop_price_data = crop_price_data.set_index(crop_price_data.index.year)

# %%
crop_price_data
# Out:
#               Price
# Month
# 2002    5184.855833
# 2003    6804.928333
# 2004    7105.751667
# 2005    6724.467500
# 2006    8705.698333
# 2007   10467.359167
# 2008   13961.342500
# 2009   10857.124167
# 2010   10204.839167
# 2011   14702.228333
# 2012   16772.254167
# 2013   18275.793333
# 2014   17371.544167
# 2015   13077.181667
# 2016   11196.448333
# 2017   11332.466667
# 2018   14379.769167
# 2019   14203.464167
# 2020   17149.716667
# 2021   23329.309167
# 2022   10997.551667

# %%
wheat_data = crop_price_data.merge(crop_land_data, left_on=crop_price_data.index,right_on=crop_land_data.Year)

# %%
wheat_data
# Out:
#       key_0         Price              State                   District  Year  \
# 0      2002   5184.855833     Andhra Pradesh                 1.ADILABAD  2002
# 1      2002   5184.855833     Andhra Pradesh                2.ANANTAPUR  2002
# 2      2002   5184.855833     Andhra Pradesh                   5.KADAPA  2002
# 3      2002   5184.855833     Andhra Pradesh                  7.KURNOOL  2002
# 4      2002   5184.855833  Arunachal Pradesh                2.CHANGLANG  2002
# ...     ...           ...                ...                        ...   ...
# 7816   2020  17149.716667        West Bengal             18.MURSHIDABAD  2020
# 7817   2020  17149.716667        West Bengal                   19.NADIA  2020
# 7818   2020  17149.716667        West Bengal   20.PASCHIM BARDHAMAN\r\n  2020
# 7819   2020  17149.716667        West Bengal         21.PURBA BARDHAMAN  2020
# 7820   2020  17149.716667        West Bengal                 22.PURULIA  2020
#
#      Year_Extra       Season  Area (Hectare)  Production (Tonnes)  \
# 0       2001-02  Rabi                 3721.0               3327.0
# 1       2001-02  Rabi                  307.0                213.0
# 2       2001-02  Rabi                   39.0                 27.0
# 3       2001-02  Rabi                 1264.0                876.0
# 4       2001-02  Rabi                  200.0                220.0
# ...         ...          ...             ...                  ...
# 7816    2019-20  Rabi                52709.0             136454.0
# 7817    2019-20  Rabi                 6188.0              16748.0
# 7818    2019-20  Rabi                  929.0               3946.0
# 7819    2019-20  Rabi                 1832.0               5678.0
# 7820    2019-20  Rabi                  516.0                931.0
#
#       Yield (Tonnes/Hectare)
# 0                       0.89
# 1                       0.69
# 2                       0.69
# 3                       0.69
# 4                       1.10
# ...                      ...
# 7816                    2.59
# 7817                    2.71
# 7818                    4.25
# 7819                    3.10
# 7820                    1.80
#
# [7821 rows x 10 columns]

# %%
wheat_data.columns
# Out:
# Index(['key_0', 'Price', 'State', 'District', 'Year', 'Year_Extra', 'Season',
#        'Area (Hectare)', 'Production (Tonnes)', 'Yield (Tonnes/Hectare)'],
#       dtype='object')

# %%
fig, axs = plt.subplots(4, figsize=(24, 12), sharex=True)

anantapur_data = wheat_data[wheat_data['District']==' 2.ANANTAPUR']
anantapur_data['Year'] = pd.to_datetime(anantapur_data['Year'], format='%Y')
anantapur_data.set_index(anantapur_data.Year, inplace=True)
anantapur_data['Price'].plot(ax = axs[0])
anantapur_data['Area (Hectare)'].plot(ax = axs[1])
anantapur_data['Production (Tonnes)'].plot(ax = axs[2])
anantapur_data['Yield (Tonnes/Hectare)'].plot(ax = axs[3])


plt.xlabel('Years')
plt.show()
# Out:
# C:\Users\kanis\AppData\Local\Temp/ipykernel_20536/1059877665.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anantapur_data['Year'] = pd.to_datetime(anantapur_data['Year'], format='%Y')

# %%
correlation_matrix = anantapur_data.corr()
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(correlation_matrix, cmap=cmap, vmax=.5, center=-1, annot=True)
plt.title("Correlation matrix for dataset")
plt.show()

# %%
fig = plot_acf(anantapur_data['Price'])
fig.set_size_inches((30, 20))
fig.tight_layout()
plt.show()

# %%
diff_price_df = anantapur_data.Price.diff()
diff_price_df.plot()
plt.title("Difference graph of price")
plt.show()

# %%
diff_price_df = anantapur_data['Production (Tonnes)'].diff()
diff_price_df.plot()
plt.title("Difference graph of price")
plt.show()
